# %% [markdown]
# # Clustering y clasificación de mood musical
#
# Este notebook continúa el análisis a partir del dataset limpio generado en `exploration.ipynb`.
#
# ## Objetivo
# Identificar grupos naturales de "mood" musical usando `valence` y `energy` (modelo circumplex de emoción musical) mediante K-Means (no supervisado), y luego entrenar un clasificador supervisado que pueda predecir el mood de una canción nueva a partir de esas etiquetas.

# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sklearn.preprocessing import StandardScaler
# from sklearn.cluster import KMeans
#
# df_clean = pd.read_csv('../data/spotify_tracks_clean.csv')
# df_clean[['valence', 'energy']].describe()
